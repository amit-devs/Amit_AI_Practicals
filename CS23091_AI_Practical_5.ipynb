# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-devs/Amit_AI_Practicals/blob/main/CS23091_AI_Practical_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import permutations

def solve(w1, w2, res):
    letters = list(set(w1 + w2 + res))
    if len(letters) > 10:
        print("No solution")
        return

    first_letters = {w1[0], w2[0], res[0]}

    for p in permutations(range(10), len(letters)):
        d = dict(zip(letters, p))

        if any(d[ch] == 0 for ch in first_letters):
            continue

        n1 = int(''.join(str(d[ch]) for ch in w1))
        n2 = int(''.join(str(d[ch]) for ch in w2))
        n3 = int(''.join(str(d[ch]) for ch in res))

        if n1 + n2 == n3:
            print("Solution:", d)
            print(n1, "+", n2, "=", n3)
            return

    print("No solution")

# Example
solve("SEND", "MORE", "MONEY")
# Out:
# Solution: {'S': 9, 'N': 6, 'E': 5, 'R': 8, 'O': 0, 'D': 7, 'M': 1, 'Y': 2}
# 9567 + 1085 = 10652
