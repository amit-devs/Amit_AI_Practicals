# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-devs/Amit_AI_Practicals/blob/main/CS23091_AI_Practical_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Amit Tiwari
# Bayes Theorem for Rain Prediction

P_cloudy = 0.40
P_rain = 0.20
P_cloudy_given_rain = 0.85

P_rain_given_cloudy = (P_rain * P_cloudy_given_rain) / P_cloudy

print("Given:")
print("P(Cloudy) =", P_cloudy)
print("P(Rain) =", P_rain)
print("P(Cloudy | Rain) =", P_cloudy_given_rain)

print("\nUsing Bayes Theorem:")

print("\nP(Rain | Cloudy) =", P_rain_given_cloudy)

print("\nIf it is cloudy, the probability that it will rain is:",
      P_rain_given_cloudy * 100, "%")
# Out:
# Given:
# P(Cloudy) = 0.4
# P(Rain) = 0.2
# P(Cloudy | Rain) = 0.85
#
# Using Bayes Theorem:
#
# P(Rain | Cloudy) = 0.425
#
# If it is cloudy, the probability that it will rain is: 42.5 %
